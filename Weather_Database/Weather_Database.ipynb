# %%
# Import the random module.
import random

# %%
# Import the NumPy module.
import numpy as np

# %%
# Import the Pandas module.
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 790

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93878aa0148fc41ed51b4907a22a3127

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rio grande
# Processing Record 2 of Set 1 | kumluca
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | malumfashi
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | rutana
# Processing Record 8 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 1 | lima
# Processing Record 10 of Set 1 | melito di porto salvo
# Processing Record 11 of Set 1 | hilo
# Processing Record 12 of Set 1 | sibolga
# Processing Record 13 of Set 1 | pisco
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | sur
# Processing Record 16 of Set 1 | tetiz
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | santa isabel do rio negro
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | yaan
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | caravelas
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | ilanskiy
# Processing Record 27 of Set 1 | marsh harbour
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | teknaf
# Processing Record 30 of Set 1 | merauke
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | port blair
# Processing Record 33 of Set 1 | pangnirtung
# Processing Record 34 of Set 1 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | prince rupert
# Processing Record 38 of Set 1 | hasaki
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | kudahuvadhoo
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | broska
# Processing Record 43 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | dandong
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | eyrarbakki
# Processing Record 49 of Set 1 | ilulissat
# Processing Record 50 of Set 1 | flinders
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | ligayan
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | marystown
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | longyearbyen
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | abu kamal
# Processing Record 10 of Set 2 | hwange
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | wattegama
# Processing Record 13 of Set 2 | bumba
# Processing Record 14 of Set 2 | turner
# Processing Record 15 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 2 | havoysund
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | rikitea
# Processing Record 19 of Set 2 | tomatlan
# Processing Record 20 of Set 2 | dongying
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | kangaatsiaq
# Processing Record 23 of Set 2 | xuanzhou
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | jiamusi
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | upernavik
# Processing Record 28 of Set 2 | luchegorsk
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | north bend
# Processing Record 31 of Set 2 | kalemie
# Processing Record 32 of Set 2 | tianpeng
# Processing Record 33 of Set 2 | vardo
# Processing Record 34 of Set 2 | huanren
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | christchurch
# Processing Record 37 of Set 2 | altay
# Processing Record 38 of Set 2 | comodoro rivadavia
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | ust-tsilma
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | san cristobal
# Processing Record 44 of Set 2 | talnakh
# Processing Record 45 of Set 2 | horsham
# Processing Record 46 of Set 2 | narsaq
# Processing Record 47 of Set 2 | abha
# Processing Record 48 of Set 2 | cervo
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | henties bay
# Processing Record 1 of Set 3 | sangrur
# Processing Record 2 of Set 3 | coihaique
# Processing Record 3 of Set 3 | port-gentil
# Processing Record 4 of Set 3 | huarmey
# Processing Record 5 of Set 3 | garwa
# Processing Record 6 of Set 3 | emerald
# Processing Record 7 of Set 3 | bulaevo
# Processing Record 8 of Set 3 | saint-francois
# Processing Record 9 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | bulgan
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | awjilah
# Processing Record 16 of Set 3 | boende
# Processing Record 17 of Set 3 | pingliang
# Processing Record 18 of Set 3 | xiaoweizhai
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 3 | locri
# Processing Record 22 of Set 3 | jyvaskyla
# Processing Record 23 of Set 3 | east london
# Processing Record 24 of Set 3 | sawtell
# Processing Record 25 of Set 3 | camargo
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | te anau
# Processing Record 29 of Set 3 | constitucion
# Processing Record 30 of Set 3 | vagay
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | samarai
# Processing Record 34 of Set 3 | toccoa
# Processing Record 35 of Set 3 | suntar
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | vestmannaeyjar
# Processing Record 38 of Set 3 | paamiut
# Processing Record 39 of Set 3 | isangel
# Processing Record 40 of Set 3 | aswan
# Processing Record 41 of Set 3 | staryy nadym
# Processing Record 42 of Set 3 | nyagan
# Processing Record 43 of Set 3 | williams lake
# Processing Record 44 of Set 3 | tutoia
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | kasempa
# Processing Record 47 of Set 3 | salta
# Processing Record 48 of Set 3 | alofi
# Processing Record 49 of Set 3 | puerto ayora
# Processing Record 50 of Set 3 | phuket
# Processing Record 1 of Set 4 | motygino
# Processing Record 2 of Set 4 | maldonado
# Processing Record 3 of Set 4 | nanakuli
# Processing Record 4 of Set 4 | paranhos
# Processing Record 5 of Set 4 | talaya
# Processing Record 6 of Set 4 | kupang
# Processing Record 7 of Set 4 | meulaboh
# Processing Record 8 of Set 4 | erdenet
# Processing Record 9 of Set 4 | tagusao
# Processing Record 10 of Set 4 | redlands
# Processing Record 11 of Set 4 | ustyuzhna
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | vostok
# Processing Record 14 of Set 4 | santa maria da vitoria
# Processing Record 15 of Set 4 | grand-santi
# Processing Record 16 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 4 | teya
# Processing Record 18 of Set 4 | richards bay
# Processing Record 19 of Set 4 | clinton
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | pinecrest
# Processing Record 23 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | santana do matos
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | kadaura
# Processing Record 28 of Set 4 | namibe
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | soyo
# Processing Record 32 of Set 4 | manono
# Processing Record 33 of Set 4 | karanja
# Processing Record 34 of Set 4 | olafsvik
# Processing Record 35 of Set 4 | lasa
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 4 | hovd
# Processing Record 39 of Set 4 | kalomo
# City not found. Skipping...
# Processing Record 40 of Set 4 | jalu
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | bilma
# Processing Record 44 of Set 4 | roma
# Processing Record 45 of Set 4 | ancud
# Processing Record 46 of Set 4 | tuzha
# Processing Record 47 of Set 4 | hami
# Processing Record 48 of Set 4 | uarini
# Processing Record 49 of Set 4 | shimoda
# Processing Record 50 of Set 4 | ampanihy
# Processing Record 1 of Set 5 | carnarvon
# Processing Record 2 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 5 | butaritari
# Processing Record 4 of Set 5 | adrar
# Processing Record 5 of Set 5 | mildura
# Processing Record 6 of Set 5 | suleja
# Processing Record 7 of Set 5 | chyhyryn
# Processing Record 8 of Set 5 | timbiras
# Processing Record 9 of Set 5 | cherskiy
# Processing Record 10 of Set 5 | puerto baquerizo moreno
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | cockburn town
# Processing Record 13 of Set 5 | formosa do rio preto
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | skibbereen
# Processing Record 17 of Set 5 | angoche
# Processing Record 18 of Set 5 | aleksandrov gay
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | cotonou
# Processing Record 21 of Set 5 | muisne
# Processing Record 22 of Set 5 | rawson
# Processing Record 23 of Set 5 | mnogovershinnyy
# Processing Record 24 of Set 5 | saint george
# Processing Record 25 of Set 5 | nacogdoches
# Processing Record 26 of Set 5 | ambilobe
# Processing Record 27 of Set 5 | moussoro
# Processing Record 28 of Set 5 | mitsamiouli
# Processing Record 29 of Set 5 | baruun-urt
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | port hedland
# Processing Record 33 of Set 5 | benguela
# Processing Record 34 of Set 5 | bow island
# Processing Record 35 of Set 5 | praxedis guerrero
# Processing Record 36 of Set 5 | port hardy
# Processing Record 37 of Set 5 | huacho
# Processing Record 38 of Set 5 | mortka
# Processing Record 39 of Set 5 | nuevitas
# Processing Record 40 of Set 5 | manggar
# Processing Record 41 of Set 5 | karratha
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | beringovskiy
# Processing Record 44 of Set 5 | saldanha
# Processing Record 45 of Set 5 | hualmay
# Processing Record 46 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 5 | kaduna
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | grand gaube
# Processing Record 50 of Set 5 | nuuk
# Processing Record 1 of Set 6 | nukus
# Processing Record 2 of Set 6 | umm kaddadah
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | boguchany
# Processing Record 5 of Set 6 | nabire
# Processing Record 6 of Set 6 | mahebourg
# Processing Record 7 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 6 | dali
# Processing Record 9 of Set 6 | wanning
# Processing Record 10 of Set 6 | kosh-agach
# Processing Record 11 of Set 6 | ipixuna
# Processing Record 12 of Set 6 | kununurra
# Processing Record 13 of Set 6 | kondinskoye
# Processing Record 14 of Set 6 | ust-kuyga
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | vila velha
# Processing Record 17 of Set 6 | gisors
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | omsukchan
# Processing Record 20 of Set 6 | dunedin
# Processing Record 21 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 22 of Set 6 | tucuman
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | zvishavane
# Processing Record 25 of Set 6 | broken hill
# Processing Record 26 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 6 | vila franca do campo
# Processing Record 28 of Set 6 | port maria
# Processing Record 29 of Set 6 | andenes
# Processing Record 30 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 6 | chuy
# Processing Record 32 of Set 6 | ishigaki
# Processing Record 33 of Set 6 | porto de moz
# Processing Record 34 of Set 6 | cordoba
# Processing Record 35 of Set 6 | labuhan
# Processing Record 36 of Set 6 | acari
# Processing Record 37 of Set 6 | talara
# Processing Record 38 of Set 6 | kermanshah
# Processing Record 39 of Set 6 | padang
# Processing Record 40 of Set 6 | sabang
# Processing Record 41 of Set 6 | quelimane
# Processing Record 42 of Set 6 | nenjiang
# Processing Record 43 of Set 6 | yeppoon
# Processing Record 44 of Set 6 | dianopolis
# City not found. Skipping...
# Processing Record 45 of Set 6 | skiathos
# Processing Record 46 of Set 6 | opuwo
# Processing Record 47 of Set 6 | tawang
# Processing Record 48 of Set 6 | muros
# Processing Record 49 of Set 6 | orocue
# Processing Record 50 of Set 6 | kuala selangor
# Processing Record 1 of Set 7 | wasilla
# Processing Record 2 of Set 7 | cooma
# Processing Record 3 of Set 7 | rovaniemi
# Processing Record 4 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 5 of Set 7 | faanui
# Processing Record 6 of Set 7 | shelburne
# Processing Record 7 of Set 7 | namwala
# Processing Record 8 of Set 7 | rudnogorsk
# Processing Record 9 of Set 7 | gat
# Processing Record 10 of Set 7 | thompson
# Processing Record 11 of Set 7 | tura
# Processing Record 12 of Set 7 | imbituba
# Processing Record 13 of Set 7 | arlit
# Processing Record 14 of Set 7 | san miguel
# Processing Record 15 of Set 7 | terrell
# Processing Record 16 of Set 7 | aksu
# Processing Record 17 of Set 7 | obuasi
# Processing Record 18 of Set 7 | gavle
# Processing Record 19 of Set 7 | oranjestad
# Processing Record 20 of Set 7 | nisia floresta
# Processing Record 21 of Set 7 | san jose
# Processing Record 22 of Set 7 | ariquemes
# Processing Record 23 of Set 7 | pemberton
# Processing Record 24 of Set 7 | bara
# Processing Record 25 of Set 7 | zamora
# Processing Record 26 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | alim
# Processing Record 28 of Set 7 | texarkana
# Processing Record 29 of Set 7 | new norfolk
# Processing Record 30 of Set 7 | pilao arcado
# City not found. Skipping...
# Processing Record 31 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 7 | turukhansk
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | sept-iles
# Processing Record 35 of Set 7 | gravdal
# Processing Record 36 of Set 7 | gasa
# Processing Record 37 of Set 7 | murupara
# Processing Record 38 of Set 7 | amga
# Processing Record 39 of Set 7 | baykit
# Processing Record 40 of Set 7 | tual
# Processing Record 41 of Set 7 | whitehorse
# Processing Record 42 of Set 7 | sassandra
# Processing Record 43 of Set 7 | eureka
# Processing Record 44 of Set 7 | kousseri
# Processing Record 45 of Set 7 | san-pedro
# Processing Record 46 of Set 7 | tamworth
# Processing Record 47 of Set 7 | aden
# Processing Record 48 of Set 7 | sumbe
# Processing Record 49 of Set 7 | kenora
# Processing Record 50 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 8 | kemri
# Processing Record 2 of Set 8 | lake charles
# Processing Record 3 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 4 of Set 8 | cidreira
# Processing Record 5 of Set 8 | kaeo
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | qasigiannguit
# Processing Record 8 of Set 8 | villarrica
# Processing Record 9 of Set 8 | ponta do sol
# Processing Record 10 of Set 8 | benjamin constant
# Processing Record 11 of Set 8 | puerto colombia
# Processing Record 12 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 13 of Set 8 | grand-lahou
# Processing Record 14 of Set 8 | juneau
# Processing Record 15 of Set 8 | ponta delgada
# Processing Record 16 of Set 8 | aykhal
# Processing Record 17 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 8 | mandurah
# Processing Record 19 of Set 8 | khandyga
# Processing Record 20 of Set 8 | edwardsville
# Processing Record 21 of Set 8 | hambantota
# Processing Record 22 of Set 8 | mandalgovi
# Processing Record 23 of Set 8 | katsuura
# Processing Record 24 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 8 | burica
# City not found. Skipping...
# Processing Record 26 of Set 8 | huilong
# Processing Record 27 of Set 8 | champerico
# Processing Record 28 of Set 8 | sulangan
# Processing Record 29 of Set 8 | itarema
# Processing Record 30 of Set 8 | terrak
# Processing Record 31 of Set 8 | ibra
# Processing Record 32 of Set 8 | auki
# Processing Record 33 of Set 8 | havelock
# Processing Record 34 of Set 8 | gifford
# Processing Record 35 of Set 8 | kabo
# Processing Record 36 of Set 8 | marfino
# Processing Record 37 of Set 8 | dumabato
# Processing Record 38 of Set 8 | kikwit
# Processing Record 39 of Set 8 | palmer
# Processing Record 40 of Set 8 | touros
# Processing Record 41 of Set 8 | berezovka
# Processing Record 42 of Set 8 | havre-saint-pierre
# Processing Record 43 of Set 8 | kaharlyk
# Processing Record 44 of Set 8 | waipawa
# Processing Record 45 of Set 8 | vanimo
# Processing Record 46 of Set 8 | saint anthony
# Processing Record 47 of Set 8 | ucluelet
# Processing Record 48 of Set 8 | arucas
# Processing Record 49 of Set 8 | rocha
# Processing Record 50 of Set 8 | flin flon
# Processing Record 1 of Set 9 | kizukuri
# Processing Record 2 of Set 9 | asfi
# Processing Record 3 of Set 9 | port-cartier
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | dukat
# Processing Record 6 of Set 9 | tiznit
# Processing Record 7 of Set 9 | saint-augustin
# Processing Record 8 of Set 9 | kruisfontein
# Processing Record 9 of Set 9 | deputatskiy
# Processing Record 10 of Set 9 | aktash
# Processing Record 11 of Set 9 | bairiki
# Processing Record 12 of Set 9 | rock springs
# Processing Record 13 of Set 9 | luanda
# Processing Record 14 of Set 9 | fort nelson
# Processing Record 15 of Set 9 | yablonovo
# Processing Record 16 of Set 9 | key largo
# Processing Record 17 of Set 9 | birigui
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | matay
# Processing Record 20 of Set 9 | loandjili
# Processing Record 21 of Set 9 | kandrian
# Processing Record 22 of Set 9 | kieta
# Processing Record 23 of Set 9 | bandarbeyla
# Processing Record 24 of Set 9 | tigil
# Processing Record 25 of Set 9 | arboletes
# Processing Record 26 of Set 9 | dongning
# Processing Record 27 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 9 | half moon bay
# Processing Record 29 of Set 9 | kulhudhuffushi
# Processing Record 30 of Set 9 | geraldton
# Processing Record 31 of Set 9 | krasnyy chikoy
# Processing Record 32 of Set 9 | kristiansund
# Processing Record 33 of Set 9 | brae
# Processing Record 34 of Set 9 | malaya vishera
# Processing Record 35 of Set 9 | nemuro
# Processing Record 36 of Set 9 | romilly-sur-seine
# Processing Record 37 of Set 9 | duxbury
# Processing Record 38 of Set 9 | galveston
# Processing Record 39 of Set 9 | radomsko
# Processing Record 40 of Set 9 | placido de castro
# Processing Record 41 of Set 9 | awbari
# Processing Record 42 of Set 9 | hervey bay
# Processing Record 43 of Set 9 | fengxian
# Processing Record 44 of Set 9 | sungai pelek
# Processing Record 45 of Set 9 | ayan
# Processing Record 46 of Set 9 | tateyama
# Processing Record 47 of Set 9 | port hawkesbury
# Processing Record 48 of Set 9 | oistins
# Processing Record 49 of Set 9 | le passage
# Processing Record 50 of Set 9 | osorno
# Processing Record 1 of Set 10 | avarua
# Processing Record 2 of Set 10 | ranong
# Processing Record 3 of Set 10 | talakan
# Processing Record 4 of Set 10 | sistranda
# Processing Record 5 of Set 10 | troitsko-pechorsk
# Processing Record 6 of Set 10 | cape canaveral
# Processing Record 7 of Set 10 | camacha
# Processing Record 8 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 9 of Set 10 | manoel urbano
# Processing Record 10 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 10 | nanortalik
# Processing Record 12 of Set 10 | salinas
# Processing Record 13 of Set 10 | aksarka
# Processing Record 14 of Set 10 | shasta lake
# Processing Record 15 of Set 10 | bethanien
# Processing Record 16 of Set 10 | najran
# Processing Record 17 of Set 10 | kamachumu
# Processing Record 18 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 10 | sao gabriel da cachoeira
# Processing Record 20 of Set 10 | belmonte
# Processing Record 21 of Set 10 | saint-philippe
# Processing Record 22 of Set 10 | rosarito
# Processing Record 23 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 10 | sitka
# Processing Record 25 of Set 10 | marmashen
# Processing Record 26 of Set 10 | natal
# Processing Record 27 of Set 10 | fulitun
# City not found. Skipping...
# Processing Record 28 of Set 10 | sao filipe
# Processing Record 29 of Set 10 | aklavik
# Processing Record 30 of Set 10 | mus
# Processing Record 31 of Set 10 | san patricio
# Processing Record 32 of Set 10 | batemans bay
# Processing Record 33 of Set 10 | san benito
# Processing Record 34 of Set 10 | romodanovo
# Processing Record 35 of Set 10 | anadyr
# Processing Record 36 of Set 10 | lianran
# Processing Record 37 of Set 10 | barela
# Processing Record 38 of Set 10 | xining
# Processing Record 39 of Set 10 | alice springs
# Processing Record 40 of Set 10 | nelson bay
# Processing Record 41 of Set 10 | edson
# Processing Record 42 of Set 10 | luderitz
# Processing Record 43 of Set 10 | yulara
# Processing Record 44 of Set 10 | mackay
# Processing Record 45 of Set 10 | sinnamary
# Processing Record 46 of Set 10 | puerto escondido
# Processing Record 47 of Set 10 | adre
# Processing Record 48 of Set 10 | sambava
# Processing Record 49 of Set 10 | sankt veit
# Processing Record 50 of Set 10 | talcahuano
# Processing Record 1 of Set 11 | valparaiso
# Processing Record 2 of Set 11 | mayo
# Processing Record 3 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | iwanai
# Processing Record 5 of Set 11 | hamilton
# Processing Record 6 of Set 11 | litovko
# Processing Record 7 of Set 11 | tsiroanomandidy
# Processing Record 8 of Set 11 | ugoofaaru
# Processing Record 9 of Set 11 | velikodvorskiy
# Processing Record 10 of Set 11 | leningradskiy
# Processing Record 11 of Set 11 | itoman
# Processing Record 12 of Set 11 | pucallpa
# Processing Record 13 of Set 11 | nyrob
# Processing Record 14 of Set 11 | shakawe
# Processing Record 15 of Set 11 | lock haven
# Processing Record 16 of Set 11 | alamosa
# Processing Record 17 of Set 11 | santa cruz del sur
# Processing Record 18 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 11 | abonnema
# Processing Record 20 of Set 11 | agadir
# Processing Record 21 of Set 11 | camapua
# Processing Record 22 of Set 11 | krasnyy luch
# Processing Record 23 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 24 of Set 11 | puerto cabezas
# Processing Record 25 of Set 11 | pangody
# Processing Record 26 of Set 11 | elko
# Processing Record 27 of Set 11 | kavieng
# Processing Record 28 of Set 11 | tazovskiy
# Processing Record 29 of Set 11 | carutapera
# Processing Record 30 of Set 11 | coroico
# Processing Record 31 of Set 11 | lujan
# Processing Record 32 of Set 11 | bayan
# Processing Record 33 of Set 11 | claye-souilly
# Processing Record 34 of Set 11 | honningsvag
# Processing Record 35 of Set 11 | makokou
# Processing Record 36 of Set 11 | komyshuvakha
# Processing Record 37 of Set 11 | piranshahr
# Processing Record 38 of Set 11 | tangshan
# Processing Record 39 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 11 | codrington
# Processing Record 41 of Set 11 | port hueneme
# Processing Record 42 of Set 11 | kidal
# Processing Record 43 of Set 11 | bella vista
# Processing Record 44 of Set 11 | louis trichardt
# Processing Record 45 of Set 11 | bushenyi
# Processing Record 46 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 11 | guasdualito
# Processing Record 48 of Set 11 | gushikawa
# Processing Record 49 of Set 11 | waingapu
# Processing Record 50 of Set 11 | murom
# Processing Record 1 of Set 12 | cahabon
# Processing Record 2 of Set 12 | preobrazheniye
# Processing Record 3 of Set 12 | husavik
# Processing Record 4 of Set 12 | zhigansk
# Processing Record 5 of Set 12 | maceio
# Processing Record 6 of Set 12 | road town
# Processing Record 7 of Set 12 | koundara
# Processing Record 8 of Set 12 | kerema
# Processing Record 9 of Set 12 | diffa
# Processing Record 10 of Set 12 | pahalgam
# Processing Record 11 of Set 12 | srednekolymsk
# Processing Record 12 of Set 12 | saint-paul
# Processing Record 13 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 12 | necochea
# Processing Record 15 of Set 12 | haverfordwest
# Processing Record 16 of Set 12 | moose factory
# Processing Record 17 of Set 12 | tucano
# Processing Record 18 of Set 12 | nome
# Processing Record 19 of Set 12 | taikang
# Processing Record 20 of Set 12 | san carlos de bariloche
# Processing Record 21 of Set 12 | upata
# Processing Record 22 of Set 12 | roald
# Processing Record 23 of Set 12 | takoradi
# Processing Record 24 of Set 12 | kauhajoki
# Processing Record 25 of Set 12 | edendale
# Processing Record 26 of Set 12 | grindavik
# Processing Record 27 of Set 12 | metro
# Processing Record 28 of Set 12 | pokhara
# Processing Record 29 of Set 12 | coquimbo
# Processing Record 30 of Set 12 | portland
# Processing Record 31 of Set 12 | biak
# Processing Record 32 of Set 12 | kachug
# Processing Record 33 of Set 12 | requena
# Processing Record 34 of Set 12 | ponnani
# Processing Record 35 of Set 12 | zaysan
# Processing Record 36 of Set 12 | puerto del rosario
# Processing Record 37 of Set 12 | zalantun
# Processing Record 38 of Set 12 | kangasala
# Processing Record 39 of Set 12 | kathu
# Processing Record 40 of Set 12 | izhma
# Processing Record 41 of Set 12 | trelew
# Processing Record 42 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 12 | yumen
# Processing Record 44 of Set 12 | sao joao da barra
# Processing Record 45 of Set 12 | poya
# Processing Record 46 of Set 12 | koygorodok
# Processing Record 47 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 12 | kuala terengganu
# Processing Record 49 of Set 12 | rio gallegos
# Processing Record 50 of Set 12 | harper
# Processing Record 1 of Set 13 | dzilam gonzalez
# Processing Record 2 of Set 13 | arnstadt
# Processing Record 3 of Set 13 | bongandanga
# Processing Record 4 of Set 13 | carballo
# Processing Record 5 of Set 13 | cabo rojo
# Processing Record 6 of Set 13 | zeya
# Processing Record 7 of Set 13 | evensk
# Processing Record 8 of Set 13 | whitianga
# Processing Record 9 of Set 13 | laguna
# Processing Record 10 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 11 of Set 13 | mehamn
# Processing Record 12 of Set 13 | nerchinskiy zavod
# Processing Record 13 of Set 13 | hailar
# Processing Record 14 of Set 13 | fairbanks
# Processing Record 15 of Set 13 | akyab
# Processing Record 16 of Set 13 | santo domingo
# Processing Record 17 of Set 13 | rancho palos verdes
# Processing Record 18 of Set 13 | scarborough
# Processing Record 19 of Set 13 | shizunai
# Processing Record 20 of Set 13 | petatlan
# Processing Record 21 of Set 13 | mporokoso
# Processing Record 22 of Set 13 | hofn
# Processing Record 23 of Set 13 | balurghat
# Processing Record 24 of Set 13 | port lincoln
# Processing Record 25 of Set 13 | nago
# Processing Record 26 of Set 13 | rongcheng
# Processing Record 27 of Set 13 | san isidro
# Processing Record 28 of Set 13 | gogrial
# Processing Record 29 of Set 13 | pemangkat
# Processing Record 30 of Set 13 | bahir dar
# Processing Record 31 of Set 13 | eyl
# Processing Record 32 of Set 13 | kalianget
# Processing Record 33 of Set 13 | svetlogorsk
# Processing Record 34 of Set 13 | laela
# Processing Record 35 of Set 13 | indianola
# Processing Record 36 of Set 13 | bud
# Processing Record 37 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 13 | sydney mines
# Processing Record 40 of Set 13 | shihezi
# Processing Record 41 of Set 13 | oktyabrskoye
# Processing Record 42 of Set 13 | key west
# Processing Record 43 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 13 | shenjiamen
# Processing Record 45 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 46 of Set 13 | thinadhoo
# Processing Record 47 of Set 13 | ballina
# Processing Record 48 of Set 13 | karonga
# Processing Record 49 of Set 13 | kralendijk
# Processing Record 50 of Set 13 | fare
# Processing Record 1 of Set 14 | belaya gora
# Processing Record 2 of Set 14 | tuatapere
# Processing Record 3 of Set 14 | atambua
# Processing Record 4 of Set 14 | tonstad
# Processing Record 5 of Set 14 | santa rosalia
# Processing Record 6 of Set 14 | buenaventura
# Processing Record 7 of Set 14 | solntsevo
# Processing Record 8 of Set 14 | kipushi
# Processing Record 9 of Set 14 | uchana
# Processing Record 10 of Set 14 | kartaly
# Processing Record 11 of Set 14 | sucua
# Processing Record 12 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | killybegs
# Processing Record 14 of Set 14 | cayenne
# Processing Record 15 of Set 14 | miraflores
# Processing Record 16 of Set 14 | baghdad
# Processing Record 17 of Set 14 | warsaw
# Processing Record 18 of Set 14 | zaozerne
# Processing Record 19 of Set 14 | marstal
# Processing Record 20 of Set 14 | tapes
# Processing Record 21 of Set 14 | gazanjyk
# Processing Record 22 of Set 14 | hamina
# Processing Record 23 of Set 14 | yerbogachen
# Processing Record 24 of Set 14 | presidencia roque saenz pena
# Processing Record 25 of Set 14 | celestun
# Processing Record 26 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 27 of Set 14 | ostrovnoy
# Processing Record 28 of Set 14 | fukue
# Processing Record 29 of Set 14 | cuajinicuilapa
# Processing Record 30 of Set 14 | vao
# Processing Record 31 of Set 14 | baymak
# Processing Record 32 of Set 14 | bjala
# City not found. Skipping...
# Processing Record 33 of Set 14 | koumac
# Processing Record 34 of Set 14 | gbarnga
# Processing Record 35 of Set 14 | makakilo city
# Processing Record 36 of Set 14 | crab hill
# City not found. Skipping...
# Processing Record 37 of Set 14 | coromandel
# Processing Record 38 of Set 14 | mujiayingzi
# Processing Record 39 of Set 14 | polessk
# Processing Record 40 of Set 14 | lorengau
# Processing Record 41 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 42 of Set 14 | amarpur
# Processing Record 43 of Set 14 | marsabit
# Processing Record 44 of Set 14 | erenhot
# Processing Record 45 of Set 14 | shirgaon
# Processing Record 46 of Set 14 | viedma
# Processing Record 47 of Set 14 | yokkaichi
# Processing Record 48 of Set 14 | castlemaine
# Processing Record 49 of Set 14 | rantepao
# Processing Record 50 of Set 14 | mount gambier
# Processing Record 1 of Set 15 | amberley
# Processing Record 2 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 15 | komsomolskiy
# Processing Record 4 of Set 15 | sri aman
# Processing Record 5 of Set 15 | seymchan
# Processing Record 6 of Set 15 | weligama
# Processing Record 7 of Set 15 | lata
# Processing Record 8 of Set 15 | pervomayskiy
# Processing Record 9 of Set 15 | kiomboi
# Processing Record 10 of Set 15 | xiaoyi
# Processing Record 11 of Set 15 | nizwa
# Processing Record 12 of Set 15 | villavicencio
# Processing Record 13 of Set 15 | khani
# Processing Record 14 of Set 15 | chicama
# Processing Record 15 of Set 15 | atasu
# Processing Record 16 of Set 15 | klaksvik
# Processing Record 17 of Set 15 | loralai
# Processing Record 18 of Set 15 | batagay-alyta
# Processing Record 19 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 21 of Set 15 | bundaberg
# Processing Record 22 of Set 15 | sayat
# Processing Record 23 of Set 15 | la serena
# Processing Record 24 of Set 15 | chipinge
# Processing Record 25 of Set 15 | sindor
# Processing Record 26 of Set 15 | cootamundra
# Processing Record 27 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 28 of Set 15 | kalmunai
# Processing Record 29 of Set 15 | sawakin
# Processing Record 30 of Set 15 | yar-sale
# Processing Record 31 of Set 15 | duki
# Processing Record 32 of Set 15 | buin
# Processing Record 33 of Set 15 | tshikapa
# Processing Record 34 of Set 15 | sorland
# Processing Record 35 of Set 15 | lincoln
# Processing Record 36 of Set 15 | orgun
# City not found. Skipping...
# Processing Record 37 of Set 15 | el dorado
# Processing Record 38 of Set 15 | crawfordsville
# Processing Record 39 of Set 15 | lodja
# Processing Record 40 of Set 15 | boralday
# Processing Record 41 of Set 15 | tanete
# Processing Record 42 of Set 15 | yabrud
# Processing Record 43 of Set 15 | siwana
# Processing Record 44 of Set 15 | houma
# Processing Record 45 of Set 15 | quatre cocos
# Processing Record 46 of Set 15 | sicuani
# Processing Record 47 of Set 15 | concepcion
# Processing Record 48 of Set 15 | banjar
# Processing Record 49 of Set 15 | taoudenni
# Processing Record 50 of Set 15 | marinskaya
# City not found. Skipping...
# Processing Record 1 of Set 16 | san rafael del sur
# Processing Record 2 of Set 16 | masinloc
# Processing Record 3 of Set 16 | ahipara
# Processing Record 4 of Set 16 | yingcheng
# Processing Record 5 of Set 16 | port-de-paix
# City not found. Skipping...
# Processing Record 6 of Set 16 | stornoway
# Processing Record 7 of Set 16 | port macquarie
# Processing Record 8 of Set 16 | galashiels
# Processing Record 9 of Set 16 | daxian
# City not found. Skipping...
# Processing Record 10 of Set 16 | dawson creek
# Processing Record 11 of Set 16 | rabo de peixe
# Processing Record 12 of Set 16 | iquitos
# Processing Record 13 of Set 16 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 14 of Set 16 | mana
# Processing Record 15 of Set 16 | naze
# Processing Record 16 of Set 16 | totness
# Processing Record 17 of Set 16 | paciran
# Processing Record 18 of Set 16 | berlevag
# Processing Record 19 of Set 16 | hobyo
# Processing Record 20 of Set 16 | juegang
# Processing Record 21 of Set 16 | babstovo
# Processing Record 22 of Set 16 | meadow lake
# Processing Record 23 of Set 16 | antalaha
# Processing Record 24 of Set 16 | bushehr
# Processing Record 25 of Set 16 | domoni
# Processing Record 26 of Set 16 | prokuplje
# Processing Record 27 of Set 16 | egvekinot
# Processing Record 28 of Set 16 | odweyne
# Processing Record 29 of Set 16 | tahoua
# Processing Record 30 of Set 16 | vyartsilya
# Processing Record 31 of Set 16 | vanavara
# Processing Record 32 of Set 16 | cap-aux-meules
# Processing Record 33 of Set 16 | tawnat
# City not found. Skipping...
# Processing Record 34 of Set 16 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 16 | varzea alegre
# Processing Record 36 of Set 16 | byron bay
# Processing Record 37 of Set 16 | datong
# Processing Record 38 of Set 16 | vestmanna
# Processing Record 39 of Set 16 | tucumcari
# Processing Record 40 of Set 16 | high level
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             Rio Grande -32.03  -52.10     62.60        36           0
# 1                Kumluca  36.37   30.29     85.80        37           0
# 2             Nikolskoye  59.70   30.79     66.20        63          40
# 3                 Dingle  11.00  122.67     76.44        89          94
# 4             Malumfashi  11.79    7.62     73.35        82          97
# 5                Mataura -46.19  168.86     39.00        97          96
# 6                 Rutana  -3.87   30.10     64.62        54          76
# 7                   Lima -12.04  -77.03     62.60        72          90
# 8  Melito Di Porto Salvo  37.92   15.77     82.40        78           0
# 9                   Hilo  19.73 -155.09     82.40        69          20
#
#    Wind Speed Country Current Description                 Date
# 0        8.05      BR           clear sky  2020-08-22 19:27:04
# 1        7.40      TR           clear sky  2020-08-22 19:27:04
# 2        4.47      RU    scattered clouds  2020-08-22 19:27:04
# 3        2.17      PH     overcast clouds  2020-08-22 19:18:32
# 4        5.12      NG     overcast clouds  2020-08-22 19:27:05
# 5        1.01      NZ     overcast clouds  2020-08-22 19:25:33
# 6        4.14      BI       broken clouds  2020-08-22 19:27:05
# 7       12.75      PE     overcast clouds  2020-08-22 19:25:03
# 8       16.11      IT           clear sky  2020-08-22 19:27:05
# 9        5.82      US          few clouds  2020-08-22 19:25:31

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Rio Grande      BR -32.03  -52.10     62.60        36           0
# 1     Kumluca      TR  36.37   30.29     85.80        37           0
# 2  Nikolskoye      RU  59.70   30.79     66.20        63          40
# 3      Dingle      PH  11.00  122.67     76.44        89          94
# 4  Malumfashi      NG  11.79    7.62     73.35        82          97
#
#    Wind Speed Current Description
# 0        8.05           clear sky
# 1        7.40           clear sky
# 2        4.47    scattered clouds
# 3        2.17     overcast clouds
# 4        5.12     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
