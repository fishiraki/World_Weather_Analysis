# %%
# Import the random module.
import random

# %%
random.randint(-90, 90)

# %%
random.random()

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
    
latitudes

# %%
random.randrange(-90, 90, step=1)

# %%
random.randrange(-90, 90, step=3)

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)

# %%
np.random.uniform(-90.000, 90.000, size=50)

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=93878aa0148fc41ed51b4907a22a3127

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | chapais
# Processing Record 5 of Set 1 | wattegama
# Processing Record 6 of Set 1 | grand gaube
# Processing Record 7 of Set 1 | kjollefjord
# Processing Record 8 of Set 1 | carutapera
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | tokur
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | saldanha
# Processing Record 15 of Set 1 | aksum
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | severo-kurilsk
# Processing Record 19 of Set 1 | mollendo
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | marsabit
# Processing Record 22 of Set 1 | monroe
# Processing Record 23 of Set 1 | amiens
# Processing Record 24 of Set 1 | bambanglipuro
# Processing Record 25 of Set 1 | chicama
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | hoa binh
# Processing Record 28 of Set 1 | nelson bay
# Processing Record 29 of Set 1 | la palma
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | zhangye
# Processing Record 33 of Set 1 | mountain home
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | skibbereen
# Processing Record 36 of Set 1 | sao jose da coroa grande
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | ocos
# Processing Record 41 of Set 1 | poso
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | castro
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | grand island
# Processing Record 46 of Set 1 | porto novo
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | bengkulu
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | comodoro rivadavia
# Processing Record 3 of Set 2 | launceston
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | naze
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | puerto ayacucho
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | sitka
# Processing Record 13 of Set 2 | alyangula
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 2 | flinders
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | gazanjyk
# Processing Record 19 of Set 2 | diamantino
# Processing Record 20 of Set 2 | basco
# Processing Record 21 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | gaborone
# Processing Record 24 of Set 2 | jinchengjiang
# City not found. Skipping...
# Processing Record 25 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 2 | shuangcheng
# Processing Record 27 of Set 2 | coquimbo
# Processing Record 28 of Set 2 | ilulissat
# Processing Record 29 of Set 2 | gigmoto
# Processing Record 30 of Set 2 | cockburn town
# Processing Record 31 of Set 2 | vostok
# Processing Record 32 of Set 2 | longyearbyen
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | marzuq
# Processing Record 37 of Set 2 | ornskoldsvik
# Processing Record 38 of Set 2 | ust-barguzin
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | upata
# Processing Record 42 of Set 2 | shingu
# Processing Record 43 of Set 2 | altamont
# Processing Record 44 of Set 2 | coihaique
# Processing Record 45 of Set 2 | moshupa
# Processing Record 46 of Set 2 | escanaba
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 2 | san cristobal
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | saint-francois
# Processing Record 3 of Set 3 | koslan
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | belaya gora
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | chumikan
# Processing Record 8 of Set 3 | inirida
# Processing Record 9 of Set 3 | faanui
# Processing Record 10 of Set 3 | kavaratti
# Processing Record 11 of Set 3 | iqaluit
# Processing Record 12 of Set 3 | albury
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | logansport
# Processing Record 16 of Set 3 | regina
# Processing Record 17 of Set 3 | villazon
# Processing Record 18 of Set 3 | richards bay
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | ostrovnoy
# Processing Record 21 of Set 3 | puerto leguizamo
# Processing Record 22 of Set 3 | shrigonda
# Processing Record 23 of Set 3 | san diego de los banos
# Processing Record 24 of Set 3 | westerland
# Processing Record 25 of Set 3 | soavinandriana
# Processing Record 26 of Set 3 | obihiro
# Processing Record 27 of Set 3 | yaan
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | tilichiki
# Processing Record 30 of Set 3 | omsukchan
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | pacific grove
# Processing Record 34 of Set 3 | broome
# Processing Record 35 of Set 3 | oranjemund
# Processing Record 36 of Set 3 | lamar
# Processing Record 37 of Set 3 | dzilam gonzalez
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | hue
# Processing Record 42 of Set 3 | hamilton
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 3 | neiafu
# Processing Record 48 of Set 3 | tunceli
# Processing Record 49 of Set 3 | touros
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | carnarvon
# Processing Record 3 of Set 4 | alta
# Processing Record 4 of Set 4 | jawhar
# Processing Record 5 of Set 4 | codrington
# Processing Record 6 of Set 4 | kenai
# Processing Record 7 of Set 4 | luanda
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | cotonou
# Processing Record 11 of Set 4 | mahibadhoo
# Processing Record 12 of Set 4 | te anau
# Processing Record 13 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 14 of Set 4 | colares
# Processing Record 15 of Set 4 | cuamba
# Processing Record 16 of Set 4 | kerouane
# Processing Record 17 of Set 4 | ushtobe
# Processing Record 18 of Set 4 | christchurch
# Processing Record 19 of Set 4 | igra
# Processing Record 20 of Set 4 | tazovskiy
# Processing Record 21 of Set 4 | itarema
# Processing Record 22 of Set 4 | thunder bay
# Processing Record 23 of Set 4 | turukhansk
# Processing Record 24 of Set 4 | kijang
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | kuah
# Processing Record 27 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 4 | ouadda
# Processing Record 29 of Set 4 | isangel
# Processing Record 30 of Set 4 | sokolo
# Processing Record 31 of Set 4 | rio grande city
# Processing Record 32 of Set 4 | saint-georges
# Processing Record 33 of Set 4 | staraya mayna
# Processing Record 34 of Set 4 | siderno
# Processing Record 35 of Set 4 | paine
# Processing Record 36 of Set 4 | tallahassee
# Processing Record 37 of Set 4 | sidi qasim
# City not found. Skipping...
# Processing Record 38 of Set 4 | moyale
# Processing Record 39 of Set 4 | butembo
# Processing Record 40 of Set 4 | barda
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | baykit
# Processing Record 43 of Set 4 | araouane
# Processing Record 44 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 4 | santiago del estero
# Processing Record 46 of Set 4 | russell
# Processing Record 47 of Set 4 | tuatapere
# Processing Record 48 of Set 4 | maceio
# Processing Record 49 of Set 4 | posse
# Processing Record 50 of Set 4 | nanning
# Processing Record 1 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 5 | gunjur
# Processing Record 3 of Set 5 | opuwo
# Processing Record 4 of Set 5 | katsuura
# Processing Record 5 of Set 5 | mikkeli
# Processing Record 6 of Set 5 | boyolangu
# Processing Record 7 of Set 5 | hambantota
# Processing Record 8 of Set 5 | mana
# Processing Record 9 of Set 5 | kulhudhuffushi
# Processing Record 10 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | ust-kulom
# Processing Record 12 of Set 5 | alice springs
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | zhigansk
# Processing Record 15 of Set 5 | yumen
# Processing Record 16 of Set 5 | panaba
# Processing Record 17 of Set 5 | cabo san lucas
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | zaozerne
# Processing Record 20 of Set 5 | dingle
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | cookeville
# Processing Record 25 of Set 5 | tabou
# Processing Record 26 of Set 5 | marawi
# Processing Record 27 of Set 5 | nova venecia
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | port macquarie
# Processing Record 31 of Set 5 | wynyard
# Processing Record 32 of Set 5 | lodja
# Processing Record 33 of Set 5 | bugene
# Processing Record 34 of Set 5 | xichang
# Processing Record 35 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | lucapa
# Processing Record 38 of Set 5 | fortuna
# Processing Record 39 of Set 5 | gizycko
# Processing Record 40 of Set 5 | kosino
# Processing Record 41 of Set 5 | marsa matruh
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | mitzic
# Processing Record 44 of Set 5 | lakes entrance
# Processing Record 45 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | hovd
# Processing Record 48 of Set 5 | canaries
# Processing Record 49 of Set 5 | olga
# Processing Record 50 of Set 5 | tigil
# Processing Record 1 of Set 6 | dicabisagan
# Processing Record 2 of Set 6 | garowe
# Processing Record 3 of Set 6 | bud
# Processing Record 4 of Set 6 | qinhuangdao
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | alto araguaia
# Processing Record 7 of Set 6 | hithadhoo
# Processing Record 8 of Set 6 | meadow lake
# Processing Record 9 of Set 6 | jalu
# Processing Record 10 of Set 6 | georgiyevka
# Processing Record 11 of Set 6 | acapulco
# Processing Record 12 of Set 6 | sao felix do xingu
# Processing Record 13 of Set 6 | edson
# Processing Record 14 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 6 | buriti alegre
# Processing Record 16 of Set 6 | dharchula
# Processing Record 17 of Set 6 | bongandanga
# Processing Record 18 of Set 6 | bozhou
# Processing Record 19 of Set 6 | misratah
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | lorengau
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | thompson
# Processing Record 24 of Set 6 | shumikha
# Processing Record 25 of Set 6 | puerto escondido
# Processing Record 26 of Set 6 | angoche
# Processing Record 27 of Set 6 | staryy nadym
# Processing Record 28 of Set 6 | miandoab
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | guerrero negro
# Processing Record 31 of Set 6 | padang
# Processing Record 32 of Set 6 | la peca
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | menongue
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | maniitsoq
# Processing Record 37 of Set 6 | popondetta
# Processing Record 38 of Set 6 | kushima
# Processing Record 39 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 41 of Set 6 | grindavik
# Processing Record 42 of Set 6 | rapid city
# Processing Record 43 of Set 6 | ramygala
# Processing Record 44 of Set 6 | saint-philippe
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | merauke
# Processing Record 47 of Set 6 | khatanga
# Processing Record 48 of Set 6 | mangai
# Processing Record 49 of Set 6 | lavello
# Processing Record 50 of Set 6 | jutai
# Processing Record 1 of Set 7 | honiara
# Processing Record 2 of Set 7 | yambio
# Processing Record 3 of Set 7 | maraba
# Processing Record 4 of Set 7 | benjamin aceval
# Processing Record 5 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 7 | myra
# Processing Record 7 of Set 7 | krasnyy kholm
# Processing Record 8 of Set 7 | nouakchott
# Processing Record 9 of Set 7 | san matias
# Processing Record 10 of Set 7 | xining
# Processing Record 11 of Set 7 | saskylakh
# Processing Record 12 of Set 7 | egvekinot
# Processing Record 13 of Set 7 | marsh harbour
# Processing Record 14 of Set 7 | roberto payan
# City not found. Skipping...
# Processing Record 15 of Set 7 | henties bay
# Processing Record 16 of Set 7 | bubaque
# Processing Record 17 of Set 7 | pisco
# Processing Record 18 of Set 7 | los lunas
# Processing Record 19 of Set 7 | clyde river
# Processing Record 20 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 7 | pevek
# Processing Record 22 of Set 7 | mecca
# Processing Record 23 of Set 7 | port blair
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | ulze
# City not found. Skipping...
# Processing Record 26 of Set 7 | georgetown
# Processing Record 27 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 7 | fairbanks
# Processing Record 29 of Set 7 | shakiso
# Processing Record 30 of Set 7 | saint george
# Processing Record 31 of Set 7 | bandar-e anzali
# Processing Record 32 of Set 7 | najran
# Processing Record 33 of Set 7 | bambous virieux
# Processing Record 34 of Set 7 | matara
# Processing Record 35 of Set 7 | saint-augustin
# Processing Record 36 of Set 7 | mamallapuram
# Processing Record 37 of Set 7 | kirksville
# Processing Record 38 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 39 of Set 7 | makakilo city
# Processing Record 40 of Set 7 | lalsk
# Processing Record 41 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 7 | smithers
# Processing Record 43 of Set 7 | ikongo
# Processing Record 44 of Set 7 | north platte
# Processing Record 45 of Set 7 | tuy hoa
# Processing Record 46 of Set 7 | airai
# Processing Record 47 of Set 7 | tendukheda
# Processing Record 48 of Set 7 | bethel
# Processing Record 49 of Set 7 | iquique
# Processing Record 50 of Set 7 | solntsevo
# Processing Record 1 of Set 8 | moroni
# Processing Record 2 of Set 8 | rio claro
# Processing Record 3 of Set 8 | oktyabrskoye
# Processing Record 4 of Set 8 | coffs harbour
# Processing Record 5 of Set 8 | vysoke
# Processing Record 6 of Set 8 | saint simons
# Processing Record 7 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 8 of Set 8 | gizo
# Processing Record 9 of Set 8 | lagoa
# Processing Record 10 of Set 8 | olinda
# Processing Record 11 of Set 8 | soto la marina
# Processing Record 12 of Set 8 | lompoc
# Processing Record 13 of Set 8 | mahbubabad
# Processing Record 14 of Set 8 | vyartsilya
# Processing Record 15 of Set 8 | matai
# Processing Record 16 of Set 8 | bathsheba
# Processing Record 17 of Set 8 | buluang
# Processing Record 18 of Set 8 | bandarbeyla
# Processing Record 19 of Set 8 | tadine
# Processing Record 20 of Set 8 | abrau-dyurso
# Processing Record 21 of Set 8 | kieta
# Processing Record 22 of Set 8 | funadhoo
# Processing Record 23 of Set 8 | tayga
# Processing Record 24 of Set 8 | bairiki
# Processing Record 25 of Set 8 | phalodi
# Processing Record 26 of Set 8 | coihueco
# Processing Record 27 of Set 8 | takoradi
# Processing Record 28 of Set 8 | the valley
# Processing Record 29 of Set 8 | ternate
# Processing Record 30 of Set 8 | qasigiannguit
# Processing Record 31 of Set 8 | vanimo
# Processing Record 32 of Set 8 | markova
# Processing Record 33 of Set 8 | kayerkan
# Processing Record 34 of Set 8 | onega
# Processing Record 35 of Set 8 | valparaiso
# Processing Record 36 of Set 8 | ca mau
# Processing Record 37 of Set 8 | ixtapa
# Processing Record 38 of Set 8 | cap malheureux
# Processing Record 39 of Set 8 | san policarpo
# Processing Record 40 of Set 8 | konya
# Processing Record 41 of Set 8 | madimba
# Processing Record 42 of Set 8 | poum
# Processing Record 43 of Set 8 | kangaatsiaq
# Processing Record 44 of Set 8 | avera
# Processing Record 45 of Set 8 | biak
# Processing Record 46 of Set 8 | duz
# City not found. Skipping...
# Processing Record 47 of Set 8 | praia da vitoria
# Processing Record 48 of Set 8 | pangody
# Processing Record 49 of Set 8 | nangal
# Processing Record 50 of Set 8 | tecoanapa
# Processing Record 1 of Set 9 | liverpool
# Processing Record 2 of Set 9 | bintulu
# Processing Record 3 of Set 9 | vila do maio
# Processing Record 4 of Set 9 | zaysan
# Processing Record 5 of Set 9 | narsaq
# Processing Record 6 of Set 9 | barra do garcas
# Processing Record 7 of Set 9 | grand-lahou
# Processing Record 8 of Set 9 | meulaboh
# Processing Record 9 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 9 | mercedes
# Processing Record 11 of Set 9 | paka
# Processing Record 12 of Set 9 | sechura
# Processing Record 13 of Set 9 | lasa
# Processing Record 14 of Set 9 | addi ugri
# City not found. Skipping...
# Processing Record 15 of Set 9 | smederevska palanka
# Processing Record 16 of Set 9 | barabai
# Processing Record 17 of Set 9 | warmbad
# Processing Record 18 of Set 9 | yelatma
# Processing Record 19 of Set 9 | mount gambier
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | belmonte
# Processing Record 22 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 9 | gueret
# Processing Record 24 of Set 9 | darnah
# Processing Record 25 of Set 9 | baghpat
# Processing Record 26 of Set 9 | thai binh
# Processing Record 27 of Set 9 | solenzo
# Processing Record 28 of Set 9 | vredendal
# Processing Record 29 of Set 9 | muncar
# Processing Record 30 of Set 9 | husavik
# Processing Record 31 of Set 9 | bull savanna
# Processing Record 32 of Set 9 | pemangkat
# Processing Record 33 of Set 9 | aguimes
# Processing Record 34 of Set 9 | peniche
# Processing Record 35 of Set 9 | kavieng
# Processing Record 36 of Set 9 | qeshm
# Processing Record 37 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 9 | buala
# Processing Record 39 of Set 9 | poya
# Processing Record 40 of Set 9 | robertsport
# Processing Record 41 of Set 9 | peleduy
# Processing Record 42 of Set 9 | salalah
# Processing Record 43 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 9 | taltal
# Processing Record 45 of Set 9 | talcahuano
# Processing Record 46 of Set 9 | chisinau
# Processing Record 47 of Set 9 | orlovskiy
# Processing Record 48 of Set 9 | ashland
# Processing Record 49 of Set 9 | fukue
# Processing Record 50 of Set 9 | kahului
# Processing Record 1 of Set 10 | tayoltita
# Processing Record 2 of Set 10 | fort nelson
# Processing Record 3 of Set 10 | mogadishu
# Processing Record 4 of Set 10 | kununurra
# Processing Record 5 of Set 10 | muhos
# Processing Record 6 of Set 10 | chiguiri arriba
# City not found. Skipping...
# Processing Record 7 of Set 10 | kasongo
# Processing Record 8 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 10 | mombetsu
# Processing Record 10 of Set 10 | eyl
# Processing Record 11 of Set 10 | hami
# Processing Record 12 of Set 10 | pinawa
# Processing Record 13 of Set 10 | negombo
# Processing Record 14 of Set 10 | raudeberg
# Processing Record 15 of Set 10 | yebaishou
# Processing Record 16 of Set 10 | turbat
# Processing Record 17 of Set 10 | tura
# Processing Record 18 of Set 10 | koumac
# Processing Record 19 of Set 10 | buchanan
# Processing Record 20 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 10 | vilhena
# Processing Record 22 of Set 10 | wilmington
# Processing Record 23 of Set 10 | erbaa
# Processing Record 24 of Set 10 | ngama
# Processing Record 25 of Set 10 | villa oliva
# City not found. Skipping...
# Processing Record 26 of Set 10 | bondoukou
# Processing Record 27 of Set 10 | honningsvag
# Processing Record 28 of Set 10 | omboue
# Processing Record 29 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 30 of Set 10 | auki
# Processing Record 31 of Set 10 | rtishchevo
# Processing Record 32 of Set 10 | maldonado
# Processing Record 33 of Set 10 | kasempa
# Processing Record 34 of Set 10 | elin pelin
# Processing Record 35 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 36 of Set 10 | san carlos de bariloche
# Processing Record 37 of Set 10 | vagur
# Processing Record 38 of Set 10 | bakchar
# Processing Record 39 of Set 10 | sao filipe
# Processing Record 40 of Set 10 | sterling
# Processing Record 41 of Set 10 | talcher
# Processing Record 42 of Set 10 | qaracala
# Processing Record 43 of Set 10 | llata
# Processing Record 44 of Set 10 | mandalgovi
# Processing Record 45 of Set 10 | churapcha
# Processing Record 46 of Set 10 | qaqortoq
# Processing Record 47 of Set 10 | nhulunbuy
# Processing Record 48 of Set 10 | rincon
# Processing Record 49 of Set 10 | yerofey pavlovich
# Processing Record 50 of Set 10 | sibiti
# Processing Record 1 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 11 | doha
# Processing Record 3 of Set 11 | syava
# Processing Record 4 of Set 11 | teahupoo
# Processing Record 5 of Set 11 | grande prairie
# Processing Record 6 of Set 11 | bella union
# Processing Record 7 of Set 11 | shimoda
# Processing Record 8 of Set 11 | westport
# Processing Record 9 of Set 11 | salgar
# Processing Record 10 of Set 11 | gold coast
# Processing Record 11 of Set 11 | zlobin
# Processing Record 12 of Set 11 | hasaki
# Processing Record 13 of Set 11 | esteli
# Processing Record 14 of Set 11 | mantua
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | dalbandin
# Processing Record 17 of Set 11 | panguna
# Processing Record 18 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 11 | bonthe
# Processing Record 20 of Set 11 | rio brilhante
# Processing Record 21 of Set 11 | neustadt
# Processing Record 22 of Set 11 | mayya
# Processing Record 23 of Set 11 | rebrikha
# Processing Record 24 of Set 11 | nnewi
# Processing Record 25 of Set 11 | pokhara
# Processing Record 26 of Set 11 | port lincoln
# Processing Record 27 of Set 11 | salinopolis
# Processing Record 28 of Set 11 | geilo
# Processing Record 29 of Set 11 | alamosa
# Processing Record 30 of Set 11 | vila velha
# Processing Record 31 of Set 11 | bijar
# Processing Record 32 of Set 11 | swift current
# Processing Record 33 of Set 11 | rosario
# Processing Record 34 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | kralendijk
# Processing Record 36 of Set 11 | madang
# Processing Record 37 of Set 11 | terrace
# Processing Record 38 of Set 11 | los llanos de aridane
# Processing Record 39 of Set 11 | ibaiti
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | arvika
# Processing Record 42 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 43 of Set 11 | natal
# Processing Record 44 of Set 11 | tucuma
# Processing Record 45 of Set 11 | lipari
# Processing Record 46 of Set 11 | yar-sale
# Processing Record 47 of Set 11 | kungurtug
# Processing Record 48 of Set 11 | jagdalpur
# Processing Record 49 of Set 11 | wuwei
# Processing Record 50 of Set 11 | soyo
# Processing Record 1 of Set 12 | mao
# Processing Record 2 of Set 12 | gamba
# Processing Record 3 of Set 12 | srednekolymsk
# Processing Record 4 of Set 12 | lanxi
# Processing Record 5 of Set 12 | weligama
# Processing Record 6 of Set 12 | effium
# Processing Record 7 of Set 12 | saint-denis
# Processing Record 8 of Set 12 | simao
# Processing Record 9 of Set 12 | tabory
# Processing Record 10 of Set 12 | sambava
# Processing Record 11 of Set 12 | ust-koksa
# Processing Record 12 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 12 | nome
# Processing Record 15 of Set 12 | kabanjahe
# Processing Record 16 of Set 12 | plettenberg bay
# Processing Record 17 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 12 | brattvag
# Processing Record 19 of Set 12 | bria
# Processing Record 20 of Set 12 | pangnirtung
# Processing Record 21 of Set 12 | rio pardo
# Processing Record 22 of Set 12 | college
# Processing Record 23 of Set 12 | tual
# Processing Record 24 of Set 12 | farafangana
# Processing Record 25 of Set 12 | ambon
# Processing Record 26 of Set 12 | balkhash
# Processing Record 27 of Set 12 | namibe
# Processing Record 28 of Set 12 | milkovo
# Processing Record 29 of Set 12 | hudson bay
# Processing Record 30 of Set 12 | abnub
# Processing Record 31 of Set 12 | kang
# Processing Record 32 of Set 12 | ganzhou
# Processing Record 33 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 12 | chinsali
# Processing Record 35 of Set 12 | hervey bay
# Processing Record 36 of Set 12 | vestmannaeyjar
# Processing Record 37 of Set 12 | talnakh
# Processing Record 38 of Set 12 | astara
# Processing Record 39 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 40 of Set 12 | qostanay
# Processing Record 41 of Set 12 | nipawin
# Processing Record 42 of Set 12 | jaque
# Processing Record 43 of Set 12 | saint-louis
# Processing Record 44 of Set 12 | soverato
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 12 | salinas
# Processing Record 48 of Set 12 | rawson
# Processing Record 49 of Set 12 | khandyga
# Processing Record 50 of Set 12 | duku
# Processing Record 1 of Set 13 | soe
# Processing Record 2 of Set 13 | yuncheng
# Processing Record 3 of Set 13 | bogorodskoye
# Processing Record 4 of Set 13 | rio grande
# Processing Record 5 of Set 13 | alofi
# Processing Record 6 of Set 13 | north bend
# Processing Record 7 of Set 13 | guanica
# Processing Record 8 of Set 13 | mendoza
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create endpoint URL with each city.
city_url = url + "&q=hilo"
    
# Run an API request for each of the cities
# Parse the JSON and retrieve data.
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -155.09, 'lat': 19.73},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 76.3,
#   'feels_like': 82.22,
#   'temp_min': 73.99,
#   'temp_max': 78.8,
#   'pressure': 1017,
#   'humidity': 78},
#  'visibility': 10000,
#  'wind': {'speed': 2.08, 'deg': 342},
#  'clouds': {'all': 1},
#  'dt': 1598123306,
#  'sys': {'type': 1,
#   'id': 7881,
#   'country': 'US',
#   'sunrise': 1598112176,
#   'sunset': 1598157814},
#  'timezone': -36000,
#  'id': 5855927,
#  'name': 'Hilo',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# %%
sorted_city_data_df = city_data_df[new_column_order]
sorted_city_data_df.head()

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
sorted_city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Files to load
city_data_to_load = "weather_data/cities.csv"

# %%
# Read the city data file and store it in a pandas DataFrame.
city_data_df = pd.read_csv(city_data_to_load)
city_data_df.head(10)

# %%
index13 = city_data_df.loc[13]
index13

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere /n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere /n for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
